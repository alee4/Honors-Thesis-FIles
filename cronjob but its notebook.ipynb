# %%
# import pandas as pd
# #https://github.com/mattpodolak/pmaw, Pushshift Multithread API Wrapper
# from pmaw import PushshiftAPI
# from datetime import datetime, timedelta


# #collect data from JoeRogan Subreddit every 2 hours, can be expanded to multiple subreddits
# def gather_data():
#     api = PushshiftAPI()
#     #https://melaniewalsh.github.io/Intro-Cultural-Analytics/04-Data-Collection/14-Reddit-Data.html

#     #year, month, day, hr, min, sec, microsec
#     before = int(datetime(2022,3,1,0,0).timestamp())
#     after = int(datetime(2022,2,22,0,0).timestamp())

#     curr_date = int(datetime.now().timestamp())
#     last_day = int((datetime.now() - timedelta(hours = 2)).timestamp())

#     limit = None

#     subreddit="JoeRogan"

# #     comments = api.search_comments(subreddit=subreddit, limit=limit, before=before, after=after)
#     comments = api.search_comments(subreddit=subreddit, limit=limit, before=curr_date, after=last_day)

#     print(f'Retrieved {len(comments)} comments from Pushshift')

#     comments_df = pd.DataFrame(comments)
    
#     curr_date_raw = datetime.now()
#     string_time = curr_date_raw.strftime('%m-%d-%Y %H:%M')

#     file_name = './' + str(string_time) + "_JoeRogan" 
    
#     comments_df.to_csv(file_name, header=True, index=False, columns=list(comments_df.axes[1]))
#     comments_df.shape

# gather_data()

# %%
# curr_date = datetime.now()
# string_time = curr_date.strftime('%m-%d-%Y %H:%M')

# file_name = './' + str(string_time) + "_JoeRogan"
# print(file_name)

# %%
import pandas as pd
#https://github.com/mattpodolak/pmaw, Pushshift Multithread API Wrapper
from pmaw import PushshiftAPI
from datetime import datetime, timedelta

#collect data from JoeRogan Subreddit every 2 hours, can be expanded to multiple subreddits
def gather_data():
    api = PushshiftAPI()
    #https://melaniewalsh.github.io/Intro-Cultural-Analytics/04-Data-Collection/14-Reddit-Data.html

    curr_date = int(datetime.now().timestamp())
    last_day = int((datetime.now() - timedelta(hours = 1)).timestamp())

    

    #JoeRogan, walkaway, WorkReform, ukraine, ivermectin, conspiracy, Russia, Coronavirus, China_Flu, HermanCainAward
    #antiwork, politics, Conservative
    
    subreddit_list = ["JoeRogan", "walkaway", "WorkReform", "ukraine", "ivermectin", "conspiracy", 
                      "Russia", "Coronavirus", "China_Flu", 
                      "HermcdanCainAward", "antiwork", "politics", "Conservative", "progressive", "Libertarian"]
    
    for subreddit in subreddit_list:
        print("start: " + subreddit)
    #   comments = api.search_comments(subreddit=subreddit, limit=limit, before=before, after=after)
        comments = api.search_comments(subreddit=subreddit, limit=limit, before=curr_date, after=last_day)

        print(f'Retrieved {len(comments)} comments from Pushshift')
    
    
        comments_df = pd.DataFrame(comments)

        curr_date_raw = datetime.now()
        string_time = curr_date_raw.strftime('%m-%d-%Y %H:%M')

        file_name = '/users/a/l/alee4/ThesisFiles/' + str(subreddit) + '/' + str(string_time) + "_" + str(subreddit)
        
        #print(file_name)
        comments_df.to_csv(file_name, header=True, index=False, columns=list(comments_df.axes[1]))

# %%
gather_data()
# Out:
# start: JoeRogan
# INFO:pmaw.PushshiftAPIBase:204 result(s) available in Pushshift
# INFO:pmaw.PushshiftAPIBase:Total:: Success Rate: 100.00% - Requests: 10 - Batches: 1 - Items Remaining: 0
# Retrieved 204 comments from Pushshift
# /users/a/l/alee4/ThesisFiles/JoeRogan/03-12-2022 00:43_JoeRogan
# start: walkaway
# INFO:pmaw.PushshiftAPIBase:68 result(s) available in Pushshift
# INFO:pmaw.PushshiftAPIBase:Total:: Success Rate: 100.00% - Requests: 10 - Batches: 1 - Items Remaining: 0
# Retrieved 68 comments from Pushshift
# /users/a/l/alee4/ThesisFiles/walkaway/03-12-2022 00:43_walkaway
# start: WorkReform
# INFO:pmaw.PushshiftAPIBase:113 result(s) available in Pushshift
# INFO:pmaw.PushshiftAPIBase:Total:: Success Rate: 100.00% - Requests: 10 - Batches: 1 - Items Remaining: 1
# INFO:pmaw.PushshiftAPIBase:1 result(s) not found in Pushshift
# Retrieved 112 comments from Pushshift
# /users/a/l/alee4/ThesisFiles/WorkReform/03-12-2022 00:43_WorkReform
# start: ukraine
# INFO:pmaw.PushshiftAPIBase:1733 result(s) available in Pushshift
# INFO:pmaw.PushshiftAPIBase:Total:: Success Rate: 100.00% - Requests: 22 - Batches: 3 - Items Remaining: 7
# INFO:pmaw.PushshiftAPIBase:7 result(s) not found in Pushshift
# Retrieved 1726 comments from Pushshift
# /users/a/l/alee4/ThesisFiles/ukraine/03-12-2022 00:44_ukraine
# start: ivermectin
# INFO:pmaw.PushshiftAPIBase:0 result(s) available in Pushshift
# Retrieved 0 comments from Pushshift
# /users/a/l/alee4/ThesisFiles/ivermectin/03-12-2022 00:44_ivermectin
# start: conspiracy
# INFO:pmaw.PushshiftAPIBase:973 result(s) available in Pushshift
# INFO:pmaw.PushshiftAPIBase:Total:: Success Rate: 100.00% - Requests: 13 - Batches: 2 - Items Remaining: 4
# INFO:pmaw.PushshiftAPIBase:4 result(s) not found in Pushshift
# Retrieved 969 comments from Pushshift
# /users/a/l/alee4/ThesisFiles/conspiracy/03-12-2022 00:44_conspiracy
# start: Russia
# INFO:pmaw.PushshiftAPIBase:0 result(s) available in Pushshift
# Retrieved 0 comments from Pushshift
# /users/a/l/alee4/ThesisFiles/Russia/03-12-2022 00:44_Russia
# start: Coronavirus
# INFO:pmaw.PushshiftAPIBase:79 result(s) available in Pushshift
# INFO:pmaw.PushshiftAPIBase:Total:: Success Rate: 100.00% - Requests: 10 - Batches: 1 - Items Remaining: 0
# Retrieved 79 comments from Pushshift
# /users/a/l/alee4/ThesisFiles/Coronavirus/03-12-2022 00:44_Coronavirus
# start: China_Flu
# INFO:pmaw.PushshiftAPIBase:0 result(s) available in Pushshift
# Retrieved 0 comments from Pushshift
# /users/a/l/alee4/ThesisFiles/China_Flu/03-12-2022 00:44_China_Flu
# start: HermanCainAward
# INFO:pmaw.PushshiftAPIBase:171 result(s) available in Pushshift
# INFO:pmaw.PushshiftAPIBase:Total:: Success Rate: 100.00% - Requests: 10 - Batches: 1 - Items Remaining: 2
# INFO:pmaw.PushshiftAPIBase:2 result(s) not found in Pushshift
# Retrieved 169 comments from Pushshift
# /users/a/l/alee4/ThesisFiles/HermanCainAward/03-12-2022 00:44_HermanCainAward
# start: antiwork
# INFO:pmaw.PushshiftAPIBase:893 result(s) available in Pushshift
# INFO:pmaw.PushshiftAPIBase:Total:: Success Rate: 100.00% - Requests: 10 - Batches: 1 - Items Remaining: 4
# INFO:pmaw.PushshiftAPIBase:4 result(s) not found in Pushshift
# Retrieved 889 comments from Pushshift
# /users/a/l/alee4/ThesisFiles/antiwork/03-12-2022 00:45_antiwork
# start: politics
# INFO:pmaw.PushshiftAPIBase:795 result(s) available in Pushshift
# INFO:pmaw.PushshiftAPIBase:Total:: Success Rate: 100.00% - Requests: 11 - Batches: 2 - Items Remaining: 1
# INFO:pmaw.PushshiftAPIBase:1 result(s) not found in Pushshift
# Retrieved 794 comments from Pushshift
# /users/a/l/alee4/ThesisFiles/politics/03-12-2022 00:45_politics
# start: Conservative
# INFO:pmaw.PushshiftAPIBase:272 result(s) available in Pushshift
# INFO:pmaw.PushshiftAPIBase:Total:: Success Rate: 100.00% - Requests: 10 - Batches: 1 - Items Remaining: 1
# INFO:pmaw.PushshiftAPIBase:1 result(s) not found in Pushshift
# Retrieved 271 comments from Pushshift
# /users/a/l/alee4/ThesisFiles/Conservative/03-12-2022 00:45_Conservative

# %% [markdown]
# ====================================
# First authenticate to zoo by running:
# ssh alee4@zoo.uvm.edu
#
#
#
# After authenticating to zoo, run:
# ssh alee4@heraclitus.uvm.edu
